# %%
#imports
import tensorflow as tf
print(tf.__version__)

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
import tensorflow_datasets as tfds

# Import existing architectures
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
# Out:
# 2.4.1

# %%
# Construct a tf.data.Dataset
(train_set, test_set), set_info = tfds.load('oxford_iiit_pet', split=['train','test'], shuffle_files=True, as_supervised=True, with_info=True)
# Out:
# Downloading and preparing dataset oxford_iiit_pet/3.2.0 (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete1TPZWL/oxford_iiit_pet-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=3680.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incomplete1TPZWL/oxford_iiit_pet-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=3669.0), HTML(value='')))
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %%
# Function that resizes images to 128x128 and then normalizes from uint8 to float32
def resize_and_normalize(image, label):
  image = tf.image.resize(image, (128, 128))
  return tf.cast(image, tf.float32) / 255., label

# %%
# Training pipeline
train_set = train_set.map(resize_and_normalize, num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_set = train_set.cache()
# train_set = train_set.shuffle(set_info.splits['train'].num_examples)
train_set = train_set.shuffle(500)
train_set = train_set.batch(64)
train_set = train_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
# Testing pipeline
test_set = test_set.map(
    resize_and_normalize, num_parallel_calls=tf.data.experimental.AUTOTUNE)
test_set = test_set.batch(64)
test_set = test_set.cache()
test_set = test_set.prefetch(tf.data.experimental.AUTOTUNE)

# %%
# Existing architectures with pretrained weights
# trained_weights = True
# existing_models = [
#     ResNet50(input_shape=(128, 128, 3), include_top=False, weights='imagenet'),
#     VGG16(input_shape=(128, 128, 3), include_top=False, weights='imagenet'),
#     MobileNetV2(input_shape=(128, 128, 3), include_top=False, weights='imagenet'),
#     DenseNet201(input_shape=(128, 128, 3), include_top=False, weights='imagenet')
#     ]

# Existing architectures without pretrained weights
trained_weights = False
existing_models = [
    ResNet50(input_shape=(128, 128, 3), include_top=False),
    VGG16(input_shape=(128, 128, 3), include_top=False),
    MobileNetV2(input_shape=(128, 128, 3), include_top=False),
    DenseNet201(input_shape=(128, 128, 3), include_top=False)
    ]

# Create empty list to store the results in
results = []

for i, existing_model in enumerate(existing_models):

    # Set the best learning rate for this architecture
    if i == 0:
        learning_rate = 0.0005
    elif i == 1:
        learning_rate = 0.0005
    elif i == 2:
        learning_rate = 0.0005
    elif i == 3:
        learning_rate = 0.0005

    # Make it so that pretrained model's layers are not trained anymore
    if trained_weights == True:
        for layer in existing_model.layers:
            layer.trainable = False

    # Create a custom output for our 37 classes
    output = Flatten()(existing_model.output)
    output = Dense(37, activation='softmax')(output)

    # Add our custom output to the model
    model = Model(existing_model.input, output)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
    )

    results.append(model.fit(
        train_set,
        epochs=50,
        validation_data=test_set,
    ))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 58/58 [==============================] - 34s 380ms/step - loss: 3.7879 - sparse_categorical_accuracy: 0.2696 - val_loss: 5.4571 - val_sparse_categorical_accuracy: 0.0273
# Epoch 2/50
# 58/58 [==============================] - 15s 252ms/step - loss: 0.6307 - sparse_categorical_accuracy: 0.8279 - val_loss: 4.0482 - val_sparse_categorical_accuracy: 0.0289
# Epoch 3/50
# 58/58 [==============================] - 15s 255ms/step - loss: 0.1354 - sparse_categorical_accuracy: 0.9679 - val_loss: 4.8403 - val_sparse_categorical_accuracy: 0.0251
# Epoch 4/50
# 58/58 [==============================] - 15s 256ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9871 - val_loss: 4.7365 - val_sparse_categorical_accuracy: 0.0267
# Epoch 5/50
# 58/58 [==============================] - 15s 258ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9947 - val_loss: 4.4921 - val_sparse_categorical_accuracy: 0.0245
# Epoch 6/50
# 58/58 [==============================] - 15s 260ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9950 - val_loss: 4.6152 - val_sparse_categorical_accuracy: 0.0297
# Epoch 7/50
# 58/58 [==============================] - 15s 261ms/step - loss: 0.0171 - sparse_categorical_accuracy: 0.9973 - val_loss: 4.4139 - val_sparse_categorical_accuracy: 0.0273
# Epoch 8/50
# 58/58 [==============================] - 15s 263ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9986 - val_loss: 4.5610 - val_sparse_categorical_accuracy: 0.0316
# Epoch 9/50
# 58/58 [==============================] - 15s 265ms/step - loss: 0.0992 - sparse_categorical_accuracy: 0.9749 - val_loss: 4.7379 - val_sparse_categorical_accuracy: 0.0240
# Epoch 10/50
# 58/58 [==============================] - 15s 265ms/step - loss: 0.2889 - sparse_categorical_accuracy: 0.9272 - val_loss: 4.5281 - val_sparse_categorical_accuracy: 0.0433
# Epoch 11/50
# 58/58 [==============================] - 15s 266ms/step - loss: 0.4327 - sparse_categorical_accuracy: 0.8809 - val_loss: 4.5046 - val_sparse_categorical_accuracy: 0.0630
# Epoch 12/50
# 58/58 [==============================] - 15s 267ms/step - loss: 0.2102 - sparse_categorical_accuracy: 0.9459 - val_loss: 4.1781 - val_sparse_categorical_accuracy: 0.1055
# Epoch 13/50
# 58/58 [==============================] - 15s 268ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9728 - val_loss: 4.0589 - val_sparse_categorical_accuracy: 0.1240
# Epoch 14/50
# 58/58 [==============================] - 16s 270ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9703 - val_loss: 4.3996 - val_sparse_categorical_accuracy: 0.1524
# Epoch 15/50
# 58/58 [==============================] - 16s 271ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9807 - val_loss: 4.5581 - val_sparse_categorical_accuracy: 0.1769
# Epoch 16/50
# 58/58 [==============================] - 16s 271ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9905 - val_loss: 3.1990 - val_sparse_categorical_accuracy: 0.3140
# Epoch 17/50
# 58/58 [==============================] - 16s 271ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9964 - val_loss: 3.4448 - val_sparse_categorical_accuracy: 0.2984
# Epoch 18/50
# 58/58 [==============================] - 16s 271ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9969 - val_loss: 2.6203 - val_sparse_categorical_accuracy: 0.4584
# Epoch 19/50
# 58/58 [==============================] - 16s 272ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9951 - val_loss: 3.3923 - val_sparse_categorical_accuracy: 0.3813
# Epoch 20/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9919 - val_loss: 3.5773 - val_sparse_categorical_accuracy: 0.3500
# Epoch 21/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0255 - sparse_categorical_accuracy: 0.9948 - val_loss: 2.8202 - val_sparse_categorical_accuracy: 0.4557
# Epoch 22/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9967 - val_loss: 2.6911 - val_sparse_categorical_accuracy: 0.4838
# Epoch 23/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.5046 - val_sparse_categorical_accuracy: 0.5108
# Epoch 24/50
# 58/58 [==============================] - 16s 273ms/step - loss: 7.8103e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.5860 - val_sparse_categorical_accuracy: 0.5151
# Epoch 25/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9994 - val_loss: 3.2537 - val_sparse_categorical_accuracy: 0.4650
# Epoch 26/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9966 - val_loss: 3.8259 - val_sparse_categorical_accuracy: 0.3745
# Epoch 27/50
# 58/58 [==============================] - 16s 275ms/step - loss: 0.0634 - sparse_categorical_accuracy: 0.9848 - val_loss: 5.5476 - val_sparse_categorical_accuracy: 0.2971
# Epoch 28/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9476 - val_loss: 5.6354 - val_sparse_categorical_accuracy: 0.2339
# Epoch 29/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.3540 - sparse_categorical_accuracy: 0.8977 - val_loss: 10.3206 - val_sparse_categorical_accuracy: 0.1853
# Epoch 30/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.2071 - sparse_categorical_accuracy: 0.9369 - val_loss: 6.8944 - val_sparse_categorical_accuracy: 0.2341
# Epoch 31/50
# 58/58 [==============================] - 16s 275ms/step - loss: 0.2217 - sparse_categorical_accuracy: 0.9472 - val_loss: 4.8522 - val_sparse_categorical_accuracy: 0.2810
# Epoch 32/50
# 58/58 [==============================] - 16s 275ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9656 - val_loss: 4.0186 - val_sparse_categorical_accuracy: 0.3647
# Epoch 33/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0645 - sparse_categorical_accuracy: 0.9801 - val_loss: 3.8973 - val_sparse_categorical_accuracy: 0.4020
# Epoch 34/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9969 - val_loss: 4.2057 - val_sparse_categorical_accuracy: 0.3996
# Epoch 35/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9935 - val_loss: 3.6143 - val_sparse_categorical_accuracy: 0.3216
# Epoch 36/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9901 - val_loss: 3.6285 - val_sparse_categorical_accuracy: 0.3778
# Epoch 37/50
# 58/58 [==============================] - 16s 275ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9926 - val_loss: 4.4657 - val_sparse_categorical_accuracy: 0.3843
# Epoch 38/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9992 - val_loss: 3.5503 - val_sparse_categorical_accuracy: 0.4290
# Epoch 39/50
# 58/58 [==============================] - 16s 273ms/step - loss: 9.6265e-04 - sparse_categorical_accuracy: 0.9998 - val_loss: 3.4009 - val_sparse_categorical_accuracy: 0.4445
# Epoch 40/50
# 58/58 [==============================] - 16s 272ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9997 - val_loss: 3.4587 - val_sparse_categorical_accuracy: 0.4394
# Epoch 41/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.0090 - sparse_categorical_accuracy: 0.9966 - val_loss: 4.5138 - val_sparse_categorical_accuracy: 0.3641
# Epoch 42/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9944 - val_loss: 4.5982 - val_sparse_categorical_accuracy: 0.3584
# Epoch 43/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9913 - val_loss: 4.7117 - val_sparse_categorical_accuracy: 0.3794
# Epoch 44/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9860 - val_loss: 10.5828 - val_sparse_categorical_accuracy: 0.1464
# Epoch 45/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9702 - val_loss: 6.7558 - val_sparse_categorical_accuracy: 0.2717
# Epoch 46/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.2525 - sparse_categorical_accuracy: 0.9590 - val_loss: 8.2702 - val_sparse_categorical_accuracy: 0.1177
# Epoch 47/50
# 58/58 [==============================] - 16s 272ms/step - loss: 0.4198 - sparse_categorical_accuracy: 0.9169 - val_loss: 9.9527 - val_sparse_categorical_accuracy: 0.1739
# Epoch 48/50
# 58/58 [==============================] - 16s 272ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.9331 - val_loss: 7.3719 - val_sparse_categorical_accuracy: 0.2066
# Epoch 49/50
# 58/58 [==============================] - 16s 274ms/step - loss: 0.1438 - sparse_categorical_accuracy: 0.9675 - val_loss: 6.6420 - val_sparse_categorical_accuracy: 0.2663
# Epoch 50/50
# 58/58 [==============================] - 16s 273ms/step - loss: 0.1444 - sparse_categorical_accuracy: 0.9691 - val_loss: 8.3450 - val_sparse_categorical_accuracy: 0.2208
# Epoch 1/50
# 58/58 [==============================] - 25s 374ms/step - loss: 3.6777 - sparse_categorical_accuracy: 0.0346 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 2/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0306 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 3/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0305 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 4/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0278 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 5/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0305 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 6/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0306 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 7/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0292 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 8/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0311 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 9/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0305 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 10/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0242 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 11/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0294 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 12/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0313 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 13/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0265 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 14/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0253 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 15/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0302 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 16/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0261 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 17/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0296 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 18/50
# 58/58 [==============================] - 19s 324ms/step - loss: 3.6110 - sparse_categorical_accuracy: 0.0250 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 19/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0246 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 20/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0244 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 21/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0265 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 22/50
# 58/58 [==============================] - 19s 324ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0246 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 23/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0315 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 24/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0234 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 25/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0287 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0270
# Epoch 26/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0270 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 27/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0229 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 28/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0205 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 29/50
# 58/58 [==============================] - 19s 324ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0269 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 30/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0241 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 31/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0229 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 32/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0263 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 33/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6114 - sparse_categorical_accuracy: 0.0221 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 34/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0263 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 35/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6114 - sparse_categorical_accuracy: 0.0249 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 36/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0204 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 37/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0181 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0270
# Epoch 38/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0247 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 39/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0251 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 40/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0199 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 41/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0195 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 42/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6111 - sparse_categorical_accuracy: 0.0244 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 43/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0264 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 44/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0219 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 45/50
# 58/58 [==============================] - 19s 324ms/step - loss: 3.6112 - sparse_categorical_accuracy: 0.0255 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0270
# Epoch 46/50
# 58/58 [==============================] - 19s 324ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0238 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 47/50
# 58/58 [==============================] - 19s 323ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0185 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 48/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0234 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 49/50
# 58/58 [==============================] - 19s 326ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0225 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 50/50
# 58/58 [==============================] - 19s 325ms/step - loss: 3.6113 - sparse_categorical_accuracy: 0.0176 - val_loss: 3.6109 - val_sparse_categorical_accuracy: 0.0273
# Epoch 1/50
# 58/58 [==============================] - 14s 171ms/step - loss: 2.1804 - sparse_categorical_accuracy: 0.5039 - val_loss: 4.6256 - val_sparse_categorical_accuracy: 0.3303
# Epoch 2/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.3770 - sparse_categorical_accuracy: 0.8942 - val_loss: 4.4957 - val_sparse_categorical_accuracy: 0.3625
# Epoch 3/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1648 - sparse_categorical_accuracy: 0.9509 - val_loss: 4.5164 - val_sparse_categorical_accuracy: 0.4148
# Epoch 4/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9523 - val_loss: 4.9564 - val_sparse_categorical_accuracy: 0.4102
# Epoch 5/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1874 - sparse_categorical_accuracy: 0.9478 - val_loss: 9.0561 - val_sparse_categorical_accuracy: 0.2685
# Epoch 6/50
# 58/58 [==============================] - 9s 148ms/step - loss: 0.1679 - sparse_categorical_accuracy: 0.9512 - val_loss: 9.9324 - val_sparse_categorical_accuracy: 0.2630
# Epoch 7/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.2293 - sparse_categorical_accuracy: 0.9366 - val_loss: 7.6422 - val_sparse_categorical_accuracy: 0.3085
# Epoch 8/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9451 - val_loss: 7.8910 - val_sparse_categorical_accuracy: 0.2649
# Epoch 9/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9259 - val_loss: 12.2153 - val_sparse_categorical_accuracy: 0.2150
# Epoch 10/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.2637 - sparse_categorical_accuracy: 0.9365 - val_loss: 8.4063 - val_sparse_categorical_accuracy: 0.2513
# Epoch 11/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9509 - val_loss: 11.8554 - val_sparse_categorical_accuracy: 0.2507
# Epoch 12/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1470 - sparse_categorical_accuracy: 0.9587 - val_loss: 13.3652 - val_sparse_categorical_accuracy: 0.2197
# Epoch 13/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1456 - sparse_categorical_accuracy: 0.9583 - val_loss: 12.5437 - val_sparse_categorical_accuracy: 0.2330
# Epoch 14/50
# 58/58 [==============================] - 9s 149ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9653 - val_loss: 12.6993 - val_sparse_categorical_accuracy: 0.2180
# Epoch 15/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1527 - sparse_categorical_accuracy: 0.9671 - val_loss: 7.0666 - val_sparse_categorical_accuracy: 0.3603
# Epoch 16/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9720 - val_loss: 8.7300 - val_sparse_categorical_accuracy: 0.2957
# Epoch 17/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1391 - sparse_categorical_accuracy: 0.9599 - val_loss: 14.9451 - val_sparse_categorical_accuracy: 0.1927
# Epoch 18/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.1531 - sparse_categorical_accuracy: 0.9637 - val_loss: 16.8099 - val_sparse_categorical_accuracy: 0.1216
# Epoch 19/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9642 - val_loss: 20.1630 - val_sparse_categorical_accuracy: 0.1431
# Epoch 20/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9759 - val_loss: 10.6245 - val_sparse_categorical_accuracy: 0.2592
# Epoch 21/50
# 58/58 [==============================] - 9s 149ms/step - loss: 0.1184 - sparse_categorical_accuracy: 0.9679 - val_loss: 10.6285 - val_sparse_categorical_accuracy: 0.2573
# Epoch 22/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9786 - val_loss: 11.7092 - val_sparse_categorical_accuracy: 0.2687
# Epoch 23/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1439 - sparse_categorical_accuracy: 0.9686 - val_loss: 8.6037 - val_sparse_categorical_accuracy: 0.3682
# Epoch 24/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9849 - val_loss: 8.0307 - val_sparse_categorical_accuracy: 0.3461
# Epoch 25/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0444 - sparse_categorical_accuracy: 0.9900 - val_loss: 9.4382 - val_sparse_categorical_accuracy: 0.3126
# Epoch 26/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0876 - sparse_categorical_accuracy: 0.9842 - val_loss: 6.4647 - val_sparse_categorical_accuracy: 0.4402
# Epoch 27/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9881 - val_loss: 9.6674 - val_sparse_categorical_accuracy: 0.3227
# Epoch 28/50
# 58/58 [==============================] - 9s 153ms/step - loss: 0.0925 - sparse_categorical_accuracy: 0.9761 - val_loss: 7.0793 - val_sparse_categorical_accuracy: 0.3639
# Epoch 29/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1178 - sparse_categorical_accuracy: 0.9726 - val_loss: 8.6326 - val_sparse_categorical_accuracy: 0.3232
# Epoch 30/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9688 - val_loss: 7.7086 - val_sparse_categorical_accuracy: 0.2769
# Epoch 31/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.1261 - sparse_categorical_accuracy: 0.9672 - val_loss: 9.0934 - val_sparse_categorical_accuracy: 0.2941
# Epoch 32/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1633 - sparse_categorical_accuracy: 0.9662 - val_loss: 8.0834 - val_sparse_categorical_accuracy: 0.3366
# Epoch 33/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.1150 - sparse_categorical_accuracy: 0.9695 - val_loss: 8.3350 - val_sparse_categorical_accuracy: 0.3679
# Epoch 34/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1271 - sparse_categorical_accuracy: 0.9700 - val_loss: 8.1311 - val_sparse_categorical_accuracy: 0.3982
# Epoch 35/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9813 - val_loss: 8.5936 - val_sparse_categorical_accuracy: 0.3797
# Epoch 36/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1341 - sparse_categorical_accuracy: 0.9757 - val_loss: 11.0109 - val_sparse_categorical_accuracy: 0.2769
# Epoch 37/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9780 - val_loss: 10.0599 - val_sparse_categorical_accuracy: 0.3162
# Epoch 38/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9872 - val_loss: 7.0238 - val_sparse_categorical_accuracy: 0.4075
# Epoch 39/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0524 - sparse_categorical_accuracy: 0.9879 - val_loss: 5.7495 - val_sparse_categorical_accuracy: 0.4563
# Epoch 40/50
# 58/58 [==============================] - 9s 152ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9930 - val_loss: 6.6288 - val_sparse_categorical_accuracy: 0.4432
# Epoch 41/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9928 - val_loss: 6.8056 - val_sparse_categorical_accuracy: 0.4644
# Epoch 42/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9906 - val_loss: 6.5690 - val_sparse_categorical_accuracy: 0.4737
# Epoch 43/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9928 - val_loss: 6.0771 - val_sparse_categorical_accuracy: 0.4944
# Epoch 44/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9787 - val_loss: 7.6929 - val_sparse_categorical_accuracy: 0.4102
# Epoch 45/50
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9817 - val_loss: 6.5559 - val_sparse_categorical_accuracy: 0.4568
# Epoch 46/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0829 - sparse_categorical_accuracy: 0.9778 - val_loss: 7.0925 - val_sparse_categorical_accuracy: 0.4088
# Epoch 47/50
# 58/58 [==============================] - 9s 149ms/step - loss: 0.0926 - sparse_categorical_accuracy: 0.9760 - val_loss: 10.6232 - val_sparse_categorical_accuracy: 0.3317
# Epoch 48/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0866 - sparse_categorical_accuracy: 0.9774 - val_loss: 9.5230 - val_sparse_categorical_accuracy: 0.3690
# Epoch 49/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.1149 - sparse_categorical_accuracy: 0.9738 - val_loss: 8.8377 - val_sparse_categorical_accuracy: 0.3530
# Epoch 50/50
# 58/58 [==============================] - 9s 150ms/step - loss: 0.0751 - sparse_categorical_accuracy: 0.9838 - val_loss: 10.1770 - val_sparse_categorical_accuracy: 0.2914
# Epoch 1/50
# 58/58 [==============================] - 50s 536ms/step - loss: 2.6964 - sparse_categorical_accuracy: 0.4199 - val_loss: 9.3994 - val_sparse_categorical_accuracy: 0.2764
# Epoch 2/50
# 58/58 [==============================] - 25s 435ms/step - loss: 0.9801 - sparse_categorical_accuracy: 0.7659 - val_loss: 6.0082 - val_sparse_categorical_accuracy: 0.4110
# Epoch 3/50
# 58/58 [==============================] - 25s 435ms/step - loss: 0.5610 - sparse_categorical_accuracy: 0.8628 - val_loss: 5.4795 - val_sparse_categorical_accuracy: 0.5121
# Epoch 4/50
# 58/58 [==============================] - 25s 435ms/step - loss: 0.3487 - sparse_categorical_accuracy: 0.9070 - val_loss: 3.3223 - val_sparse_categorical_accuracy: 0.5585
# Epoch 5/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.3603 - sparse_categorical_accuracy: 0.9119 - val_loss: 5.7672 - val_sparse_categorical_accuracy: 0.4298
# Epoch 6/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.9128 - val_loss: 6.1681 - val_sparse_categorical_accuracy: 0.4279
# Epoch 7/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.2739 - sparse_categorical_accuracy: 0.9299 - val_loss: 4.1998 - val_sparse_categorical_accuracy: 0.5478
# Epoch 8/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.2411 - sparse_categorical_accuracy: 0.9437 - val_loss: 4.0051 - val_sparse_categorical_accuracy: 0.5421
# Epoch 9/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1937 - sparse_categorical_accuracy: 0.9528 - val_loss: 3.2643 - val_sparse_categorical_accuracy: 0.5448
# Epoch 10/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.2906 - sparse_categorical_accuracy: 0.9362 - val_loss: 4.5113 - val_sparse_categorical_accuracy: 0.4857
# Epoch 11/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.4641 - sparse_categorical_accuracy: 0.9145 - val_loss: 11.6966 - val_sparse_categorical_accuracy: 0.3366
# Epoch 12/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.9015 - val_loss: 11.8320 - val_sparse_categorical_accuracy: 0.3818
# Epoch 13/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.3668 - sparse_categorical_accuracy: 0.9203 - val_loss: 7.5277 - val_sparse_categorical_accuracy: 0.4323
# Epoch 14/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.2330 - sparse_categorical_accuracy: 0.9465 - val_loss: 3.7051 - val_sparse_categorical_accuracy: 0.5803
# Epoch 15/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1628 - sparse_categorical_accuracy: 0.9611 - val_loss: 3.6026 - val_sparse_categorical_accuracy: 0.5773
# Epoch 16/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.1197 - sparse_categorical_accuracy: 0.9727 - val_loss: 4.1876 - val_sparse_categorical_accuracy: 0.5715
# Epoch 17/50
# 58/58 [==============================] - 25s 436ms/step - loss: 0.1051 - sparse_categorical_accuracy: 0.9782 - val_loss: 2.7781 - val_sparse_categorical_accuracy: 0.6062
# Epoch 18/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.1110 - sparse_categorical_accuracy: 0.9773 - val_loss: 3.5479 - val_sparse_categorical_accuracy: 0.6108
# Epoch 19/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9727 - val_loss: 3.8293 - val_sparse_categorical_accuracy: 0.5754
# Epoch 20/50
# 58/58 [==============================] - 25s 436ms/step - loss: 0.1075 - sparse_categorical_accuracy: 0.9733 - val_loss: 5.3898 - val_sparse_categorical_accuracy: 0.5279
# Epoch 21/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.1379 - sparse_categorical_accuracy: 0.9732 - val_loss: 3.4890 - val_sparse_categorical_accuracy: 0.5882
# Epoch 22/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9788 - val_loss: 5.4959 - val_sparse_categorical_accuracy: 0.5159
# Epoch 23/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9726 - val_loss: 4.3633 - val_sparse_categorical_accuracy: 0.5506
# Epoch 24/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9526 - val_loss: 12.9072 - val_sparse_categorical_accuracy: 0.4609
# Epoch 25/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.3591 - sparse_categorical_accuracy: 0.9362 - val_loss: 9.9183 - val_sparse_categorical_accuracy: 0.3737
# Epoch 26/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.5879 - sparse_categorical_accuracy: 0.8980 - val_loss: 13.2394 - val_sparse_categorical_accuracy: 0.3181
# Epoch 27/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.2958 - sparse_categorical_accuracy: 0.9369 - val_loss: 6.2543 - val_sparse_categorical_accuracy: 0.4696
# Epoch 28/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.2488 - sparse_categorical_accuracy: 0.9520 - val_loss: 5.9943 - val_sparse_categorical_accuracy: 0.4246
# Epoch 29/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.2119 - sparse_categorical_accuracy: 0.9593 - val_loss: 19.3614 - val_sparse_categorical_accuracy: 0.2922
# Epoch 30/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1602 - sparse_categorical_accuracy: 0.9668 - val_loss: 6.1360 - val_sparse_categorical_accuracy: 0.5230
# Epoch 31/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.3150 - sparse_categorical_accuracy: 0.9478 - val_loss: 14.1753 - val_sparse_categorical_accuracy: 0.3873
# Epoch 32/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.3131 - sparse_categorical_accuracy: 0.9531 - val_loss: 6.5975 - val_sparse_categorical_accuracy: 0.5358
# Epoch 33/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.3590 - sparse_categorical_accuracy: 0.9418 - val_loss: 8.1426 - val_sparse_categorical_accuracy: 0.4775
# Epoch 34/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.3124 - sparse_categorical_accuracy: 0.9486 - val_loss: 7.9835 - val_sparse_categorical_accuracy: 0.4756
# Epoch 35/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1935 - sparse_categorical_accuracy: 0.9627 - val_loss: 4.6154 - val_sparse_categorical_accuracy: 0.5767
# Epoch 36/50
# 58/58 [==============================] - 25s 436ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9820 - val_loss: 4.1024 - val_sparse_categorical_accuracy: 0.5844
# Epoch 37/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9929 - val_loss: 3.1227 - val_sparse_categorical_accuracy: 0.6083
# Epoch 38/50
# 58/58 [==============================] - 25s 439ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9973 - val_loss: 2.8850 - val_sparse_categorical_accuracy: 0.6470
# Epoch 39/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9986 - val_loss: 2.9568 - val_sparse_categorical_accuracy: 0.6342
# Epoch 40/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9978 - val_loss: 3.2593 - val_sparse_categorical_accuracy: 0.6389
# Epoch 41/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9961 - val_loss: 4.1880 - val_sparse_categorical_accuracy: 0.5658
# Epoch 42/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.0500 - sparse_categorical_accuracy: 0.9894 - val_loss: 3.4554 - val_sparse_categorical_accuracy: 0.5854
# Epoch 43/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9887 - val_loss: 5.9149 - val_sparse_categorical_accuracy: 0.4958
# Epoch 44/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9834 - val_loss: 6.1586 - val_sparse_categorical_accuracy: 0.5050
# Epoch 45/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.1570 - sparse_categorical_accuracy: 0.9773 - val_loss: 5.4517 - val_sparse_categorical_accuracy: 0.5206
# Epoch 46/50
# 58/58 [==============================] - 25s 436ms/step - loss: 0.2709 - sparse_categorical_accuracy: 0.9594 - val_loss: 6.3755 - val_sparse_categorical_accuracy: 0.3429
# Epoch 47/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.4902 - sparse_categorical_accuracy: 0.9249 - val_loss: 8.6851 - val_sparse_categorical_accuracy: 0.3987
# Epoch 48/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.5173 - sparse_categorical_accuracy: 0.9220 - val_loss: 8.5549 - val_sparse_categorical_accuracy: 0.4513
# Epoch 49/50
# 58/58 [==============================] - 25s 438ms/step - loss: 0.4101 - sparse_categorical_accuracy: 0.9452 - val_loss: 11.4046 - val_sparse_categorical_accuracy: 0.3707
# Epoch 50/50
# 58/58 [==============================] - 25s 437ms/step - loss: 0.5393 - sparse_categorical_accuracy: 0.9257 - val_loss: 7.6845 - val_sparse_categorical_accuracy: 0.4982

# %%
# Plotting imports
import matplotlib.pyplot as plt
from google.colab import files
from matplotlib.pyplot import figure

# %%
# Plot the accuracy
for i,result in enumerate(results):
    if i == 0:
        plt.plot(result.history["sparse_categorical_accuracy"], label="ResNet50")
    elif i == 1:
        plt.plot(result.history["sparse_categorical_accuracy"], label="VGG16")
    elif i == 2:
        plt.plot(result.history["sparse_categorical_accuracy"], label="MobileNetV2")
    elif i == 3:
        plt.plot(result.history["sparse_categorical_accuracy"], label="DenseNet201")

plt.title("Training accuracy per epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.savefig("untrained_training_acc.png")
files.download("untrained_training_acc.png")

# %%
# Plot the validation accuracy
for i,result in enumerate(results):
    if i == 0:
        plt.plot(result.history["val_sparse_categorical_accuracy"], label="ResNet50")
    elif i == 1:
        plt.plot(result.history["val_sparse_categorical_accuracy"], label="VGG16")
    elif i == 2:
        plt.plot(result.history["val_sparse_categorical_accuracy"], label="MobileNetV2")
    elif i == 3:
        plt.plot(result.history["val_sparse_categorical_accuracy"], label="DenseNet201")

plt.title("Validation accuracy per epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.savefig("untrained_validation_acc.png")
files.download("untrained_validation_acc.png")

# %%
# Plot the loss
for i,result in enumerate(results):
    if i == 0:
        plt.plot(result.history["loss"], label="ResNet50")
    elif i == 1:
        plt.plot(result.history["loss"], label="VGG16")
    elif i == 2:
        plt.plot(result.history["loss"], label="MobileNetV2")
    elif i == 3:
        plt.plot(result.history["loss"], label="DenseNet201")

plt.title("Training loss per epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Loss", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.savefig("untrained_training_loss.png")
files.download("untrained_training_loss.png")

# %%
# Plot the validation loss
for i,result in enumerate(results):
    if i == 0:
        plt.plot(result.history["val_loss"], label="ResNet50")
    elif i == 1:
        plt.plot(result.history["val_loss"], label="VGG16")
    elif i == 2:
        plt.plot(result.history["val_loss"], label="MobileNetV2")
    elif i == 3:
        plt.plot(result.history["val_loss"], label="DenseNet201")

plt.title("Validation loss per epoch", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Loss", fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc=1, fontsize=12)
plt.savefig("untrained_validation_loss.png")
files.download("untrained_validation_loss.png")

# %%
import numpy as np

for i,result in enumerate(results):
    print(i, ": \n")
    # Calculate and print the average accuracies over the last 5 epochs
    avg_acc = np.mean(result.history["sparse_categorical_accuracy"][-5:])
    avg_val_acc = np.mean(result.history["val_sparse_categorical_accuracy"][-5:])

    print("Average acc. = " , avg_acc)
    print("Average val. acc. = " , avg_val_acc)
# Out:
# 0 :
#
# Average acc. =  0.9489130496978759
# Average val. acc. =  0.19705641865730286
# 1 :
#
# Average acc. =  0.02304347828030586
# Average val. acc. =  0.027255382388830185
# 2 :
#
# Average acc. =  0.9777717471122742
# Average val. acc. =  0.35077677965164183
# 3 :
#
# Average acc. =  0.9361956477165222
# Average val. acc. =  0.41237394213676454
